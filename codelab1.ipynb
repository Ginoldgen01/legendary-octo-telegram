# %% [markdown]
# <img src="Logo.jpg">
# <h1><center>UNIVERSIDAD DE MANILA</center></h1>
# <h3><br><center><b>College of Engineering and Technology</b></center></br><h3>
#
# <h5>Name: Ginoldgen Gracio</h5>
# <h5>Section: BSCYB-11/CS11</h5>
# <h5>Professor Mr. Ryan Azur</h5>
#
# <br><h5><center>Assignment:<b> Code Lab 01<center><h5><br>

# %%
character_name = "Ginoldgen"
print("There was a girl named with her first name, + ".)
print(She loves to express what her self is.)
